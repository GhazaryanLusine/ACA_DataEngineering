# %%
import pandas as pd
import numpy as np

# %%
from PIL import Image 
img= Image.open('Booking.jpg')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=937x884 at 0x2650DB3FAC0>

# %%
Guest= pd.read_csv(r"data_guest.csv", index_col=False)

# %%
Guest.head()
# Out:
#    Guest_ID Guest_name Guest_surname                 Guest_email Guest_gender  \
# 0    969901     Ferris       Chilles     fchilles0@blinklist.com         Male
# 1    527923    Thedric          Side      tside1@stumbleupon.com         Male
# 2    229512     Sharla       Genders        sgenders2@google.com         Male
# 3    654919      Alyce       Sunners  asunners3@reverbnation.com         Male
# 4    533628      Issie      Greenham       igreenham4@tumblr.com       Female
#
#   Guest_country Guest_date_of_birth
# 0        Brazil          1998-12-27
# 1         China          1978-03-17
# 2        Russia          1962-02-03
# 3        Poland          1989-10-31
# 4         Syria          1997-04-08

# %%
Tour_Agent= pd.read_csv(r"tour_agent.csv", index_col=False)

# %%
Tour_Agent.head()
# Out:
#    Tour_Agent     Agent_name         Agent_email   Agent_phone
# 0        2394  Ashien Belitz  abelitz0@github.io  416-890-1165
# 1        5486   Cathe Deener  cdeener1@google.es  220-370-0556
# 2        3375       Lou Stag      lstag2@icq.com  944-730-9999
# 3        3469  Marcella Vany      mvany3@ted.com  551-632-1370
# 4        5385   Omar Brunsen  obrunsen4@java.com  624-800-0633

# %%
Booking=pd.read_csv(r"Booking.csv", dtype={'Guest_id':'object', 'Agent_id':'object'})

# %%
Booking=Booking[['Booking_id', 'Room_id', 'Guest_id','Agent_id','Date_from','Date_to']]
Booking.head()
# Out:
#    Booking_id  Room_id Guest_id Agent_id   Date_from     Date_to
# 0       79113      735   321073      NaN  2022-01-10  2022-01-17
# 1       50398      358   999991      NaN  2022-01-13  2022-02-26
# 2       36324      909   658699      NaN  2022-01-05  2022-01-15
# 3       99779      768      NaN     5486  2022-01-12  2022-02-15
# 4       39367      730      NaN     3375  2022-01-05  2022-02-15

# %%
Country=pd.read_csv(r"Country.csv")
Country.head()
# Out:
#   Country_name Country_code Country_currency
# 0       Canada           CA              CAD
# 1       Sweden           SE              SEK
# 2     Ethiopia           ET              ETB
# 3       Mexico           MX              MXN
# 4        Spain           ES              EUR

# %%
Service_booking=pd.read_csv(r"Service_booking.csv")

# %%
Service_booking.head()
# Out:
#    Booking_id Service_id Service_type
# 0       96697         R5   Restaurant
# 1       98351        T16         Tour
# 2       69061        T42         Tour
# 3       31059         R9   Restaurant
# 4       97690        R30   Restaurant

# %%
Review = pd.read_csv(r"Review.csv", index_col=False)
Review.head()
# Out:
#   Hotel_id  Hotel_review  review_count
# 0       H1           6.3           306
# 1       H2           8.4          1089
# 2       H3           6.7           488
# 3       H4           9.8           389
# 4       H5           9.4          1165

# %%
Hotels = pd.read_csv(r"Hotels.csv", index_col=False)
Hotels.head()
# Out:
#   Hotel_id                 Hotel_name  Hotel_star
# 0       H1       Hotel Antiche Figure           5
# 1       H2  Rhea Silvia Luxury Navona           5
# 2       H3              Academy Hotel           3
# 3       H4                 Casa Selce           5
# 4       H5       Abramo Affittacamere           5

# %%
Cars = pd.read_csv(r"Cars.csv", index_col=False)
Cars.head()
# Out:
#   Car_id   Car_make   Car_model Car_dailyrate
# 0     C1   Infiniti           Q      $1347.03
# 1     C2  Chevrolet     Venture      $1051.38
# 2     C3      Mazda  Miata MX-5       $989.12
# 3     C4   Chrysler         300       $633.93
# 4     C5       Jeep    Cherokee       $905.99

# %%
Tours = pd.read_csv(r"Tours.csv", index_col=False)
Tours.head()
# Out:
#   Tours_id                                               name  rating  \
# 0       T1  Electric scooter tour inside the Valley of the...     5.0
# 1       T2  Jewish Ghetto and Navona Food Wine and Sightse...     5.0
# 2       T3                      Pizza and Gelato Making Class     5.0
# 3       T4  Skip the Line: Hard Rock Cafe Venice Including...     4.0
# 4       T5  Underground Rome:Capuchin Crypts And Museum En...     5.0
#
#   Tour_price
# 0       165$
# 1       166$
# 2        85$
# 3        75$
# 4       112$

# %%
Restaurant= pd.read_csv(r"Restaurant.csv", index_col=False)
Restaurant.head()
# Out:
#   Restaurant_id                                  Name  \
# 0            R1                    Tavernetta al Molo
# 1            R2  Osteria "El Cassetin" di Milos Marco
# 2            R3             Marise Osteria Con Cucina
# 3            R4           Sbecolez Osteria con cucina
# 4            R5                Al Nuovo Antico Pavone
#
#                         Email                 Phone  Rating  Review_Count
# 0  tavernettaalmolo@libero.it    tel:+39 040 224275     4.5          2372
# 1        elcassetin@gmail.com    tel:+39 040 764322     4.5           114
# 2       info@osteriamarise.it  tel:+39 040 322 9149     4.5           822
# 3                         NaN  tel:+39 040 064 4279     4.5           205
# 4   info@nuovoanticopavone.it    tel:+39 040 303899     4.5           436
